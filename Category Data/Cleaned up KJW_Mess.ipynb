# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import re
# %matplotlib inline

# %%
df = pd.read_csv('item_sales_summary_2015-06-01_2016-01-31.csv')

# %%
cateList = list();
for category in pd.unique(df['Category']):
    cateList.append(df[df['Category'] == category])

# %%
writer = pd.ExcelWriter("Unique Category.xlsx")
dfcat = pd.unique(df['Category']);
i = 0
for data in cateList:
    data.to_excel(writer,dfcat[i])
    i += 1
writer.save()

# %%
cateList[0]
# Out:
#                                Item Name  Item Variation          SKU  \
# 0                          Custom Amount  No description          NaN
# 1                         2D Printer Use   Regular Price          NaN
# 2                   4- Up Playset Black          Regular  74427845759
# 3                    4- Up Playset White   Regular Price  74427846046
# 4                         9 Page Sleeves         Regular          NaN
# 5                  Americana cherry cola   Regular Price  39771113121
# 6    Angels Mtg From The Vault Pre-order   Regular Price          NaN
# 7         Battlelore: Hernfar Guardians          Regular     9.78E+12
# 8          Battlelore: Warband of Scorn          Regular     9.78E+12
# 9                            Bones 77124         Regular     7.62E+11
# 10                          Catan Junior   Regular Price          NaN
# 11                           Chaos Draft   Regular Price          NaN
# ...

# %%
pd.unique(df['Category'])

# %%
sums = df.groupby("Category").sum()
mean = df.groupby("Category").mean()
writer = pd.ExcelWriter("Category Data.xlsx")
sums.to_excel(writer, 'Category Sums')
mean.to_excel(writer, 'Category Mean')
writer.save()

# %%
def sq_data(x):
    x**2

# %%
isq = df['Items Sold'].apply(sq_data)

# %%
isq.head()
# Out:
# 0    None
# 1    None
# 2    None
# 3    None
# 4    None
# Name: Items Sold, dtype: object

# %%
unc = df[df['Category']=='Uncategorized']
itemsum = np.sum(unc['Items Sold'])
itemsum

# %%
cols = pd.unique(df['Category'])
