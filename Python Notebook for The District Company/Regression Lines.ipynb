# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.linear_model import LinearRegression
# %matplotlib inline
os.chdir("Files")

# %%
sns.set(style='whitegrid',context='notebook')
filename = "TransposedSales.csv"
df = pd.read_csv(filename, index_col = 0)
df.head()
# Out:
#           Uncategorized  Beverages  Board Games  Bottled Beverages    Candy  \
# Category
# 6/1/2015        0.00000     0.0045      0.13985            0.06491  0.00250
# 6/2/2015        0.01703     0.0020      0.00000            0.09296  0.00630
# 6/3/2015        0.00350     0.0000      0.05999            0.07796  0.00630
# 6/4/2015        0.00200     0.0000      0.00000            0.06095  0.00520
# 6/5/2015        0.01999     0.0000      0.00000            0.10846  0.00555
#
#           Canned Beverages  Card Gaming Accessories  Event Tickets     Food  \
# Category
# 6/1/2015            0.0090                  0.00799           0.01  0.03448
# 6/2/2015            0.0430                  0.00000           0.00  0.06214
# 6/3/2015            0.0580                  0.00000           0.02  0.06529
# 6/4/2015            0.0465                  0.15891           0.36  0.06566
# 6/5/2015            0.0245                  0.00000           0.27  0.06348
#
# ...

# %%
cols = ["Candy","Food"]
sns.lmplot("Candy","Food", df[cols])

# %%
#cols = ['Beverages','Candy']
#sns.pairplot(df, size=2.5, kind="reg");

# %%
cols2 = ['Uncategorized','Beverages','Board Games','Bottled Beverages','Candy','Canned Beverages','Card Gaming Accessories','Event Tickets','Food','Glass Bottled Soda']
cols = ['Uncategorized','Beverages','Board Games','Bottled Beverages']
g = sns.PairGrid(df[cols], size=2.5);


xlabels,ylabels = [],[]
g.axes.xaxis.
for ax in g.axes[-1,:]:
    xlabel = ax.xaxis.get_label_text()
    xlabels.append(xlabel)
for ax in g.axes[:,]:
    ylabel = ax.yaxis.get_label_text()
    ylabels.append(ylabel)

for i in range(len(xlabels)):
    for j in range(len(ylabels)):
        g.axes[j,i].xaxis.set_label_text(xlabels[i])
        g.axes[j,i].yaxis.set_label_text(ylabels[j])

plt.show()
# Out:
#   File "<ipython-input-5-e2908c548c39>", line 7
#     g.axes.xaxis.
#                  ^
# SyntaxError: invalid syntax

# %%
cols = ['Magic The Gathering','Food']
sns.lmplot('Magic The Gathering','Food', data=df[cols], fit_reg = "true", scatter = "false", truncate = "false")

# %%
cols = ['Magic The Gathering', 'Food']
g = sns.lmplot('Magic The Gathering','Food', data=df[cols], fit_reg = "true", scatter = "false", truncate = "false")
axes = g.axes
axes[0,0].set_xlim(-.5,3.5)
axes[0,0].set_ylim(-.05,.3)
# Out:
# (-0.05, 0.3)

# %%
cols = ['Magic The Gathering', 'Bottled Beverages']
g = sns.lmplot('Magic The Gathering','Bottled Beverages', data=df[cols], fit_reg = "true", scatter = "false", truncate = "false")
axes = g.axes
axes[0,0].set_xlim(-.5,3.5)
axes[0,0].set_ylim(-.05,.3)
# Out:
# (-0.05, 0.3)

# %%
cols = ['Magic The Gathering', 'Event Tickets']
g = sns.lmplot('Magic The Gathering','Event Tickets', data=df[cols], fit_reg = "true", scatter = "false", truncate = "false")
axes = g.axes
axes[0,0].set_xlim(-.5,3.5)
axes[0,0].set_ylim(-.05,.3)
# Out:
# (-0.05, 0.3)

# %%
cols = ['Food', 'Event Tickets']
g = sns.lmplot('Food','Event Tickets', data=df[cols], fit_reg = "true", scatter = "false", truncate = "false")
axes = g.axes
axes[0,0].set_xlim(-.5,3.5)
axes[0,0].set_ylim(-.05,.3)
# Out:
# (-0.05, 0.3)

# %%
cols = ['Magic The Gathering','Event Tickets','Board Games']
sns.pairplot(df[cols], size=2.5, kind="reg");
