# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.linear_model import LinearRegression
# %matplotlib inline

# %%
sns.set(style='whitegrid',context='notebook')

# %%
filename = "category-sales-2015-06-01-2016-01-31.csv"
data = pd.read_csv(filename)

# %%
df = data.T

# %%
for n in range(df.shape[1]):
    df.rename(columns={df.columns[n]: df.iloc[0,n]}, inplace=True)

# %%
df = df[1:]

# %%
df.head()
# Out:
#          Uncategorized Beverages Board Games Bottled Beverages    Candy  \
# 6/1/2015             0    0.0045     0.13985           0.06491   0.0025
# 6/2/2015       0.01703     0.002           0           0.09296   0.0063
# 6/3/2015        0.0035         0     0.05999           0.07796   0.0063
# 6/4/2015         0.002         0           0           0.06095   0.0052
# 6/5/2015       0.01999         0           0           0.10846  0.00555
#
#          Canned Beverages Card Gaming Accessories Event Tickets     Food  \
# 6/1/2015            0.009                 0.00799          0.01  0.03448
# 6/2/2015            0.043                       0             0  0.06214
# 6/3/2015            0.058                       0          0.02  0.06529
# 6/4/2015           0.0465                 0.15891          0.36  0.06566
# 6/5/2015           0.0245                       0          0.27  0.06348
#
#          Glass Bottled Soda    ...     Venue Fee Birthdays D&D Dragon Ball Z  \
# 6/1/2015              0.026    ...             0         0   0             0
# 6/2/2015               0.08    ...             0         0   0             0
# 6/3/2015              0.056    ...             0         0   0             0
# 6/4/2015              0.053    ...             0         0   0             0
# 6/5/2015              0.071    ...             0         0   0             0
#
#          Clothing Star Wars Miniatures  Video Gaming Figures And Models  \
# 6/1/2015        0         0           0            0                  0
# 6/2/2015        0         0           0            0                  0
# 6/3/2015        0         0           0            0                  0
# 6/4/2015        0         0           0            0                  0
# 6/5/2015        0         0           0            0                  0
#
#          WarMachine
# 6/1/2015          0
# 6/2/2015          0
# 6/3/2015          0
# 6/4/2015          0
# 6/5/2015          0
#
# [5 rows x 34 columns]

# %%
df.columns
# Out:
# Index(['Uncategorized', 'Beverages', 'Board Games', 'Bottled Beverages',
#        'Candy', 'Canned Beverages', 'Card Gaming Accessories', 'Event Tickets',
#        'Food', 'Glass Bottled Soda',
#        'MTG Sealed (booster packs, fat packs, etc)', 'Novelties', 'Pokemon',
#        'Card Game', 'Network', 'Dice and accessories', 'Netrunner', 'Yu-Gi-Oh',
#        'Magic The Gathering', 'Warhammer 40K', 'Force of Will',
#        'Miscellaneous', '3D printing', 'Prize Support', 'Venue Fee',
#        'Birthdays', 'D&D', 'Dragon Ball Z', 'Clothing', 'Star Wars',
#        'Miniatures ', 'Video Gaming', 'Figures And Models', 'WarMachine'],
#       dtype='object')

# %%
cols = ['Candy','Video Gaming','Board Games','D&D']
cols2 = ['Uncategorized', 'Beverages', 'Board Games', 'Bottled Beverages',
       'Candy', 'Canned Beverages', 'Card Gaming Accessories', 'Event Tickets',
       'Food', 'Glass Bottled Soda',
       'MTG Sealed (booster packs, fat packs, etc)', 'Novelties', 'Pokemon',
       'Card Game', 'Network', 'Dice and accessories', 'Netrunner', 'Yu-Gi-Oh',
       'Magic The Gathering', 'Warhammer 40K', 'Force of Will',
       'Miscellaneous', '3D printing', 'Prize Support', 'Venue Fee',
       'Birthdays', 'D&D', 'Dragon Ball Z', 'Clothing', 'Star Wars',
       'Miniatures ', 'Video Gaming', 'Figures And Models', 'WarMachine', '6/1/2015']

# %%
sns.pairplot(df[cols],size=2.5);
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 31

# %%
X = df[['Video Gaming']].values
y = df['Candy'].values

# %%
slr = LinearRegression()
slr.fit(X, y)
y_pred = slr.predict(X)
print('Slope: %.3f' % slr.coef_[0])
print('Intercept: %.3f' % slr.intercept_)
# Out:
# Slope: 0.623
# Intercept: 0.004

# %%
def lin_regplot(X, y, model):
    plt.scatter(X, y, c='lightblue')
    plt.plot(X, model.predict(X), color='red', linewidth=2)    
    return

# %%
lin_regplot(X, y, slr)
plt.xlabel('Video Games')
plt.ylabel('Candy')
plt.tight_layout()

# %%
sns.lmplot("Board Games", "Food", hue="6/1/2015", data=df[cols2])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-29-4460e74d27e3> in <module>()
#       1
# ----> 2 sns.lmplot("Board Games", "Food", hue="Drinks", data=df[cols2])
#
# C:\Users\Student\Anaconda3\lib\site-packages\seaborn\linearmodels.py in lmplot(x, y, data, hue, col, row, palette, col_wrap, size, aspect, markers, sharex, sharey, hue_order, col_order, row_order, legend, legend_out, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, x_jitter, y_jitter, scatter_kws, line_kws)
#     534     need_cols = [x, y, hue, col, row, units, x_partial, y_partial]
#     535     cols = np.unique([a for a in need_cols if a is not None]).tolist()
# --> 536     data = data[cols]
#     537
#     538     # Initialize the grid
#
# C:\Users\Student\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    1961         if isinstance(key, (Series, np.ndarray, Index, list)):
#    1962             # either boolean or fancy integer index
# -> 1963             return self._getitem_array(key)
#    1964         elif isinstance(key, DataFrame):
#    1965             return self._getitem_frame(key)
#
# C:\Users\Student\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_array(self, key)
#    2005             return self.take(indexer, axis=0, convert=False)
#    2006         else:
# -> 2007             indexer = self.ix._convert_to_indexer(key, axis=1)
#    2008             return self.take(indexer, axis=1, convert=True)
#    2009
#
# C:\Users\Student\Anaconda3\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, obj, axis, is_setter)
#    1148                 mask = check == -1
#    1149                 if mask.any():
# -> 1150                     raise KeyError('%s not in index' % objarr[mask])
#    1151
#    1152                 return _values_from_object(indexer)
#
# KeyError: "['Drinks'] not in index"
