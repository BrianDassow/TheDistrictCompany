# %% [markdown]
# ##### The District Company

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('june2015throughjan2016.csv')
df.head()
df.transpose().head()
# Out:
#                      0          1            2                  3      4   \
# Category  Uncategorized  Beverages  Board Games  Bottled Beverages  Candy
# 6/1/2015              0          0         0.14               0.06      0
# 6/2/2015           0.02          0            0               0.09   0.01
# 6/3/2015              0          0         0.06               0.08   0.01
# 6/4/2015              0          0            0               0.06   0.01
#
#                         5                        6              7     8   \
# Category  Canned Beverages  Card Gaming Accessories  Event Tickets  Food
# 6/1/2015              0.01                     0.01           0.01  0.03
# 6/2/2015              0.04                        0              0  0.06
# 6/3/2015              0.06                        0           0.02  0.07
# 6/4/2015              0.05                     0.16           0.36  0.07
#
#                           9      ...             24         25   26  \
# ...

# %%
df[0:-1]
# Out:
#                                       Category  6/1/2015  6/2/2015  6/3/2015  \
# 0                                Uncategorized      0.00      0.02      0.00
# 1                                    Beverages      0.00      0.00      0.00
# 2                                  Board Games      0.14      0.00      0.06
# 3                            Bottled Beverages      0.06      0.09      0.08
# 4                                        Candy      0.00      0.01      0.01
# 5                             Canned Beverages      0.01      0.04      0.06
# 6                      Card Gaming Accessories      0.01      0.00      0.00
# 7                                Event Tickets      0.01      0.00      0.02
# 8                                         Food      0.03      0.06      0.07
# 9                           Glass Bottled Soda      0.03      0.08      0.06
# 10  MTG Sealed (booster packs, fat packs, etc)      0.25      0.04      0.00
# ...

# %%
cols = ['weekday','temp','hum','windspeed','cnt']
plt.scatter(df['Figures And Models'],df['6/1/2015']);plt.xlabel('6/1/2015');plt.ylabel('0');
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-59-9f8ee01348c8> in <module>()
#       1 cols = ['weekday','temp','hum','windspeed','cnt']
# ----> 2 plt.scatter(df['Figures And Models'],df['6/1/2015']);plt.xlabel('6/1/2015');plt.ylabel('0');
#
# C:\Users\Student\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    1967             return self._getitem_multilevel(key)
#    1968         else:
# -> 1969             return self._getitem_column(key)
#    1970
#    1971     def _getitem_column(self, key):
#
# C:\Users\Student\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    1974         # get column
#    1975         if self.columns.is_unique:
# -> 1976             return self._get_item_cache(key)
#    1977
#    1978         # duplicate columns & possible reduce dimensionality
#
# ...
