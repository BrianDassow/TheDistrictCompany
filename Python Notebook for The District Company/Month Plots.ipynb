# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.linear_model import LinearRegression
# %matplotlib inline
os.chdir("Files")

# %%
sns.set(style='whitegrid',context='notebook')
filename = "months.csv"
df = pd.read_csv(filename, index_col = 0)
df.head()
# Out:
#                       June     July   August  September  October  November   \
# Category
# Uncategorized      0.47962  0.86241  2.95429    0.42982  0.51582    0.19855
# Beverages          0.07450  0.17000  0.16850    0.18150  0.15150    0.10600
# Board Games        1.24887  1.18274  1.73031    1.77186  1.73124    1.53843
# Bottled Beverages  1.63081  1.22281  1.35791    1.62670  1.71473    1.35897
# Candy              0.09830  0.09530  0.12285    0.09945  0.17025    0.15210
#
#                    December  January
# Category
# Uncategorized       0.24216  0.26146
# Beverages           0.06000  0.07100
# Board Games         2.86319  0.98865
# Bottled Beverages   1.30717  1.80666
# Candy               0.14310  0.30309

# %%
totals = df.sum()
totals.head()
# Out:
# June         30.06044
# July         34.10215
# August       34.46072
# September    37.53719
# October      41.03104
# dtype: float64

# %%
my_plot = totals.plot(kind='bar')

# %%
my_plot3 = df.plot(kind='bar',stacked=True,title="Total Sales by Customer")
my_plot3.set_xlabel("Item")
my_plot3.set_ylabel("Sales")
my_plot3.legend(df, loc='center left', ncol=2,bbox_to_anchor=(1.2, 0.5))

# %%
sns.set(style='whitegrid',context='notebook')
filename = "months.csv"
data = pd.read_csv(filename)
df = data.T
for n in range(df.shape[1]):
    df.rename(columns={df.columns[n]: df.iloc[0,n]}, inplace=True)
df = df[1:]
df.head()
# Out:
#           Uncategorized Beverages Board Games Bottled Beverages    Candy  \
# June            0.47962    0.0745     1.24887           1.63081   0.0983
# July            0.86241      0.17     1.18274           1.22281   0.0953
# August          2.95429    0.1685     1.73031           1.35791  0.12285
# September       0.42982    0.1815     1.77186            1.6267  0.09945
# October         0.51582    0.1515     1.73124           1.71473  0.17025
#
#           Canned Beverages Card Gaming Accessories Event Tickets     Food  \
# June                0.8165                 0.34625          1.66  2.09965
# July                 0.849                 0.43992         1.012  2.03518
# August              1.0125                 0.30885         1.498  2.04499
# September           0.9335                 0.63485         3.249   2.4955
# October            0.63525                  0.9281          2.11  2.42791
#
#           Glass Bottled Soda    ...     Venue Fee Birthdays      D&D  \
# ...

# %%
my_plot3 = df.plot(kind='bar',stacked=True,title="Total Sales by Customer")
my_plot3.set_xlabel("Wednesdays")
my_plot3.set_ylabel("Sales")
my_plot3.legend(df, loc='center left', ncol=2,bbox_to_anchor=(1.2, 0.5))

# %%
df = data.T
for n in range(df.shape[1]):
    df.rename(columns={df.columns[n]: df.iloc[0,n]}, inplace=True)
df = df[1:]
df = df.ix[0:-1,0:7]
my_plot3 = df.plot(kind='bar',stacked=False,title="Total Sales by Customer")
my_plot3.set_xlabel("Wednesdays")
my_plot3.set_ylabel("Sales")
my_plot3.legend(df, loc='center left', ncol=2,bbox_to_anchor=(1.2, 0.5))

# %%
df = data.T
for n in range(df.shape[1]):
    df.rename(columns={df.columns[n]: df.iloc[0,n]}, inplace=True)
df = df[1:]
df = df.ix[0:-1,7:14]
my_plot3 = df.plot(kind='bar',stacked=False,title="Total Sales by Customer")
my_plot3.set_xlabel("Wednesdays")
my_plot3.set_ylabel("Sales")
my_plot3.legend(df, loc='center left', ncol=2,bbox_to_anchor=(1.2, 0.5))

# %%
df = data.T
for n in range(df.shape[1]):
    df.rename(columns={df.columns[n]: df.iloc[0,n]}, inplace=True)
df = df[1:]
df = df.ix[0:-1,14:21]
my_plot3 = df.plot(kind='bar',stacked=False,title="Total Sales by Customer")
my_plot3.set_xlabel("Wednesdays")
my_plot3.set_ylabel("Sales")
my_plot3.legend(df, loc='center left', ncol=2,bbox_to_anchor=(1.2, 0.5))

# %%
sns.pairplot(df,size=2.5);

# %% [markdown]
# # Look here for Data

# %%
sns.set(style='whitegrid',context='notebook')
filename = "months.csv"
data = pd.read_csv(filename)
df = data.T
for n in range(df.shape[1]):
    df.rename(columns={df.columns[n]: df.iloc[0,n]}, inplace=True)
df = df[1:]
df.head()
# Out:
#           Uncategorized Beverages Board Games Bottled Beverages    Candy  \
# June            0.47962    0.0745     1.24887           1.63081   0.0983
# July            0.86241      0.17     1.18274           1.22281   0.0953
# August          2.95429    0.1685     1.73031           1.35791  0.12285
# September       0.42982    0.1815     1.77186            1.6267  0.09945
# October         0.51582    0.1515     1.73124           1.71473  0.17025
#
#           Canned Beverages Card Gaming Accessories Event Tickets     Food  \
# June                0.8165                 0.34625          1.66  2.09965
# July                 0.849                 0.43992         1.012  2.03518
# August              1.0125                 0.30885         1.498  2.04499
# September           0.9335                 0.63485         3.249   2.4955
# October            0.63525                  0.9281          2.11  2.42791
#
#           Glass Bottled Soda    ...     Venue Fee Birthdays      D&D  \
# ...

# %%
my_plot3 = df.plot(kind='bar',stacked=True,title="Total Revenue")
my_plot3.set_xlabel("Months")
my_plot3.set_ylabel("Revenue")
my_plot3.legend(df, loc='center left', ncol=2,bbox_to_anchor=(1.2, 0.5))

# %% [markdown]
# ## This is a br

# %%
df1 = df.ix[0:-1,0:7]
my_plot3 = df1.plot(kind='bar',stacked=False,title="Total Sales by Customers")
my_plot3.set_xlabel("Month")
my_plot3.set_ylabel("Sales")
my_plot3.legend(df1, loc='center left', ncol=2,bbox_to_anchor=(1.2, 0.5))
df1.head()
# Out:
#           Uncategorized Beverages Board Games Bottled Beverages    Candy  \
# June            0.47962    0.0745     1.24887           1.63081   0.0983
# July            0.86241      0.17     1.18274           1.22281   0.0953
# August          2.95429    0.1685     1.73031           1.35791  0.12285
# September       0.42982    0.1815     1.77186            1.6267  0.09945
# October         0.51582    0.1515     1.73124           1.71473  0.17025
#
#           Canned Beverages Card Gaming Accessories
# June                0.8165                 0.34625
# July                 0.849                 0.43992
# August              1.0125                 0.30885
# September           0.9335                 0.63485
# October            0.63525                  0.9281

# %%
df2 = df.ix[0:-1,7:14]
my_plot3 = df2.plot(kind='bar',stacked=False,title="Total Sales by Customers")
my_plot3.set_xlabel("Month")
my_plot3.set_ylabel("Sales")
my_plot3.legend(df2, loc='center left', ncol=2,bbox_to_anchor=(1.2, 0.5))
df2.head()
# Out:
#           Event Tickets     Food Glass Bottled Soda mtg sealed  Novelties  \
# June               1.66  2.09965             3.0355     3.05043   12.6108
# July              1.012  2.03518             3.9065     0.82708   8.62273
# August            1.498  2.04499              3.561     0.36859   6.45154
# September         3.249   2.4955              2.956     0.86304   5.19061
# October            2.11  2.42791              3.057     0.71021   2.90163
#
#            Pokemon Card Game
# June       0.29086    0.4917
# July       0.04797   2.07568
# August     2.37091   0.94523
# September  0.64807   1.25169
# October    1.02483   0.80373

# %%
df3 = df.ix[0:-1,14:21]
my_plot3 = df3.plot(kind='bar',stacked=False,title="Total Sales by Customers")
my_plot3.set_xlabel("Month")
my_plot3.set_ylabel("Sales")
my_plot3.legend(df3, loc='center left', ncol=2,bbox_to_anchor=(1.2, 0.5))
df3.head()
# Out:
#           Network Dice and accessories Netrunner Yu-Gi-Oh      mtg  \
# June        0.571              0.15388   0.01399   0.4281  0.18261
# July        0.655              0.13211         0  0.25083   7.4427
# August      0.866              0.14983         0  1.38754  5.33041
# September   0.699              0.29394         0  1.11482  10.9791
# October     0.871              0.21604   0.01495  1.50157  15.4825
#
#           Warhammer 40K Force of Will
# June            0.26925       0.39696
# July            0.39873       1.63039
# August           0.2754       1.32936
# September       0.01495       1.39279
# October           0.246       2.85822

# %%
df4 = df.ix[0:-1,21:28]
my_plot3 = df4.plot(kind='bar',stacked=False,title="Total Sales by Customers")
my_plot3.set_xlabel("Month")
my_plot3.set_ylabel("Sales")
my_plot3.legend(df4, loc='center left', ncol=2,bbox_to_anchor=(1.2, 0.5))
df4.head()
# Out:
#           Miscellaneous 3D printing Prize Support Venue Fee Birthdays  \
# June                0.1      0.0109             0         0         0
# July            0.17907       0.024             0      0.04         0
# August          0.12472     0.05699         0.015         0      0.03
# September        0.0295     0.16274             0         0      0.03
# October         0.07948       0.088             0         0      0.08
#
#                D&D Dragon Ball Z
# June             0             0
# July             0             0
# August           0             0
# September  0.48874             0
# October     0.4415       0.23359

# %%
df5 = df.ix[0:-1,28:34]
my_plot3 = df5.plot(kind='bar',stacked=False,title="Total Sales by Customers")
my_plot3.set_xlabel("Month")
my_plot3.set_ylabel("Sales")
my_plot3.legend(df5, loc='center left', ncol=2,bbox_to_anchor=(1.2, 0.5))
df5.head()
# Out:
#           Clothing Star Wars Miniatures  Video Gaming Figures And Models  \
# June             0         0           0            0                  0
# July             0         0           0            0                  0
# August           0         0           0            0                  0
# September        0         0           0            0                  0
# October      0.036         0           0            0                  0
#
#           WarMachine
# June               0
# July               0
# August             0
# September          0
# October            0

# %%
filename = "monthsTransposed.csv"
df = pd.read_csv('monthsTransposed.csv', index_col = 0)
df.head()
# Out:
#            Uncategorized  Beverages  Board Games  Bottled Beverages    Candy  \
# Category
# June             0.47962     0.0745      1.24887            1.63081  0.09830
# July             0.86241     0.1700      1.18274            1.22281  0.09530
# August           2.95429     0.1685      1.73031            1.35791  0.12285
# September        0.42982     0.1815      1.77186            1.62670  0.09945
# October          0.51582     0.1515      1.73124            1.71473  0.17025
#
#            Canned Beverages  Card Gaming Accessories  Event Tickets     Food  \
# Category
# June                0.81650                  0.34625          1.660  2.09965
# July                0.84900                  0.43992          1.012  2.03518
# August              1.01250                  0.30885          1.498  2.04499
# September           0.93350                  0.63485          3.249  2.49550
# October             0.63525                  0.92810          2.110  2.42791
#
# ...

# %%
cols = ['mtg','Event Tickets','Board Games']
sns.pairplot(df[cols], size=2.5, kind="reg");
